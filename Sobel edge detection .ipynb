# %% [markdown]
# <a href="https://colab.research.google.com/github/prithweeraaj/Computer-Vision-/blob/main/Sobel%20edge%20detection%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img = cv.imread("/content/drive/MyDrive/COMPUTER VISION /sudoku1.jpg",cv.IMREAD_GRAYSCALE)
plt.imshow(img,cmap='gray')

# %%
sobelx=cv.Sobel(img,-1,0,1,3)
plt.imshow(sobelx,cmap='gray')
plt.title("sobelx")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(489.5), np.float64(367.5), np.float64(-0.5))

# %%
sobely=cv.Sobel(img,-1,1,0,3)
plt.imshow(sobely,cmap='gray')
plt.title("sobely")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(489.5), np.float64(367.5), np.float64(-0.5))

# %%
sobely=cv.Sobel(img,-1,0,1,3)
sobely=cv.Sobel(img,-1,1,0,3)
sobelx=cv.convertScaleAbs(sobelx)
sobely=cv.convertScaleAbs(sobely)
sobelxy=cv.addWeighted(sobelx,1,sobely,1,0)
plt.imshow(sobelxy,cmap='gray')
plt.title("dx and dy combained ")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(489.5), np.float64(367.5), np.float64(-0.5))

# %%
laplacian=cv.Laplacian(img,-1,3)
plt.imshow(laplacian,cmap="gray")
plt.title("laplacian")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(489.5), np.float64(367.5), np.float64(-0.5))
