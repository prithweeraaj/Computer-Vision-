# %% [markdown]
# <a href="https://colab.research.google.com/github/prithweeraaj/Computer-Vision-/blob/main/CV%20class%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import Libraries
import cv2
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

# %%
image_pathe='/content/drive/MyDrive/COMPUTER VISION /download (1).jpg'
image=cv2.imread(image_pathe)
plt.imshow(image)

# %% [markdown]
# # open cv

# %%
import cv2
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

# %%
image1='/content/drive/MyDrive/COMPUTER VISION /download (1).jpg'
image=cv2.imread(image1)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
 plt.imshow(image)

# %%
cv2.imwrite('out_orange.jpg',image)
# Out:
# True

# %%
image_rgb=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)

# %%
cv2_imshow(image_rgb)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %% [markdown]
# in open cv in bulid BGR  format instead of RGB. when we display the function the channels are interpreted BGR.
